# %%
# Import Dependencies
import seaborn as sns
import pandas as pd
import re
import numpy as np
from sqlalchemy import create_engine
import psycopg2
from config import db_password

# %%
# Create connection to the PostgreSQL database.
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/Wine_Ratings"
cnx = create_engine(db_string).connect()
  
# table named 'wine_data' will be returned as a dataframe.
wine_df = pd.read_sql_table('wine_data', cnx)
print(wine_df)
# Out:
#         wine_no   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                         None      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                    None      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                    None      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna               None
# 1                   Douro                 None               None
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore               None
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                 None               None
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace               None
# 129969             Alsace               Alsace               None
# 129970             Alsace               Alsace               None
#
#                taster_name taster_twitter  \
# 0            Kerin O’Keefe   @kerinokeefe
# 1               Roger Voss     @vossroger
# 2             Paul Gregutt    @paulgwine
# 3       Alexander Peartree           None
# 4             Paul Gregutt    @paulgwine
# ...                    ...            ...
# 129966  Anna Lee C. Iijima           None
# 129967        Paul Gregutt    @paulgwine
# 129968          Roger Voss     @vossroger
# 129969          Roger Voss     @vossroger
# 129970          Roger Voss     @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 14 columns]

# %% [markdown]
# # Transformation & Data Cleanup

# %%
# Return number of rows and columns for raw dataframe.
wine_df.shape
# Out:
# (129971, 14)

# %%
# Print summary info for all columns in dataframe.
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   wine_no         129971 non-null  int64
#  1   country         129908 non-null  object
#  2   description     129971 non-null  object
#  3   designation     92506 non-null   object
#  4   points          129971 non-null  int64
#  5   price           120975 non-null  float64
#  6   province        129908 non-null  object
#  7   region_1        108724 non-null  object
#  8   region_2        50511 non-null   object
#  9   taster_name     103727 non-null  object
#  10  taster_twitter  98758 non-null   object
#  11  title           129971 non-null  object
#  12  variety         129970 non-null  object
#  13  winery          129971 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 13.9+ MB

# %% [markdown]
# ## Add year column to df

# %%
# Create list of titles to prepare for year extraction.
titles_list = list(wine_df["title"].values)
print(titles_list[0:10])
# Out:
# ['Nicosia 2013 Vulkà Bianco  (Etna)', 'Quinta dos Avidagos 2011 Avidagos Red (Douro)', 'Rainstorm 2013 Pinot Gris (Willamette Valley)', 'St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)', "Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)", 'Tandem 2011 Ars In Vitro Tempranillo-Merlot (Navarra)', 'Terre di Giurfo 2013 Belsito Frappato (Vittoria)', 'Trimbach 2012 Gewurztraminer (Alsace)', 'Heinz Eifel 2013 Shine Gewürztraminer (Rheinhessen)', 'Jean-Baptiste Adam 2012 Les Natures Pinot Gris (Alsace)']

# %%
# loop through titles and store years from 21st century to list.
years = []
for i, title in enumerate(titles_list):
    try:
        year = re.search(r"\b(20)\d{2}\b", title).group(0)
        years.append(year)
    except:
        years.append(np.NaN)
print(years[0:10])
# Out:
# ['2013', '2011', '2013', '2013', '2012', '2011', '2013', '2012', '2013', '2012']

# %%
# Add extracted year column to dataframe.
wine_df["year"] = years
wine_df.head()
# Out:
#    wine_no   country                                        description  \
# 0        0     Italy  Aromas include tropical fruit, broom, brimston...
# 1        1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        2        US  Tart and snappy, the flavors of lime flesh and...
# 3        3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                None      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name taster_twitter  \
# 0                 Etna               None       Kerin O’Keefe   @kerinokeefe
# 1                 None               None          Roger Voss     @vossroger
# 2    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
# 3  Lake Michigan Shore               None  Alexander Peartree           None
# 4    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery  year
# 0              Nicosia  2013
# 1  Quinta dos Avidagos  2011
# 2            Rainstorm  2013
# 3           St. Julian  2013
# 4         Sweet Cheeks  2012

# %%
# check stats for year column.
wine_df['year'].describe()
# Out:
# count     123626
# unique        18
# top         2013
# freq       15875
# Name: year, dtype: object

# %%
# Print summary info for all columns in revised dataframe.
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   wine_no         129971 non-null  int64
#  1   country         129908 non-null  object
#  2   description     129971 non-null  object
#  3   designation     92506 non-null   object
#  4   points          129971 non-null  int64
#  5   price           120975 non-null  float64
#  6   province        129908 non-null  object
#  7   region_1        108724 non-null  object
#  8   region_2        50511 non-null   object
#  9   taster_name     103727 non-null  object
#  10  taster_twitter  98758 non-null   object
#  11  title           129971 non-null  object
#  12  variety         129970 non-null  object
#  13  winery          129971 non-null  object
#  14  year            123626 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 14.9+ MB

# %% [markdown]
# ## Add type column to df for red and white categories

# %%
# Create list of descriptions to examine for adding wine type feature.
description_list = list(wine_df["description"].values)
print(description_list[0:10])
# Out:
# ["Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.", "This is ripe and fruity, a wine that is smooth while still structured. Firm tannins are filled out with juicy red berry fruits and freshened with acidity. It's  already drinkable, although it will certainly be better from 2016.", 'Tart and snappy, the flavors of lime flesh and rind dominate. Some green pineapple pokes through, with crisp acidity underscoring the flavors. The wine was all stainless-steel fermented.', 'Pineapple rind, lemon pith and orange blossom start off the aromas. The palate is a bit more opulent, with notes of honey-drizzled guava and mango giving way to a slightly astringent, semidry finish.', "Much like the regular bottling from 2012, this comes across as rather rough and tannic, with rustic, earthy, herbal characteristics. Nonetheless, if you think of it as a pleasantly unfussy country wine, it's a good companion to a hearty winter stew.", 'Blackberry and raspberry aromas show a typical Navarran whiff of green herbs and, in this case, horseradish. In the mouth, this is fairly full bodied, with tomatoey acidity. Spicy, herbal flavors complement dark plum fruit, while the finish is fresh but grabby.', "Here's a bright, informal red that opens with aromas of candied berry, white pepper and savory herb that carry over to the palate. It's balanced with fresh acidity and soft tannins.", "This dry and restrained wine offers spice in profusion. Balanced with acidity and a firm texture, it's very much for food.", "Savory dried thyme notes accent sunnier flavors of preserved peach in this brisk, off-dry wine. It's fruity and fresh, with an elegant, sprightly footprint.", "This has great depth of flavor with its fresh apple and pear fruits and touch of spice. It's off dry while balanced with acidity and a crisp texture. Drink now."]

# %%
# Testing.
wine_df['variety'].str.contains('red').value_counts()
# Out:
# False    129906
# True         64
# Name: variety, dtype: int64

# %%
# Read in text file and convert to dictionary for red grape varieties.
red_dictionary = {}
file = open('Resources/Red dictionary.txt',
            encoding='utf-8')
for line in file:
    key,value = line.split()
    red_dictionary[key] = value

# %%
# Replace underscores with spaces in dictionary keys.
corrected_red_dict = {k.replace('_', ' '): v for k, v in red_dictionary.items()}

# %%
# Read in text file and convert to dictionary for white grape varieties.
white_dictionary = {}
file = open('Resources/White dictionary.txt',
           encoding='utf-8')
for line in file:
    key,value = line.split()
    white_dictionary[key] = value

# %%
# Replace underscores with spaces in dictionary keys.
corrected_white_dict = {k.replace('_', ' '): v for k, v in white_dictionary.items()}

# %%
# Create function to merge two dictionaries.
def merge_dicts(x, y):
    z = x.copy()
    z.update(y)
    return z

# Merge red and white dictionaries.
merged_type_dict = merge_dicts(corrected_red_dict, corrected_white_dict)

# %%
# Create function to check features (variety, title, and description) against type dictionary and assign new red/white feature.
wine_type = merged_type_dict

def fill_type(feature):
    for key in wine_type:
        if key.lower() in feature.lower():
            return wine_type[key]
    return np.NaN

# %%
# STEP 1 - Call function and create new column for red and white wine types 
# Look in variety column for dictionary key and return red or white value.
wine_df["type"] = wine_df["variety"].astype(str).map(lambda feature: fill_type(feature))
wine_df.head()
# Out:
#    wine_no   country                                        description  \
# 0        0     Italy  Aromas include tropical fruit, broom, brimston...
# 1        1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        2        US  Tart and snappy, the flavors of lime flesh and...
# 3        3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                None      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name taster_twitter  \
# 0                 Etna               None       Kerin O’Keefe   @kerinokeefe
# 1                 None               None          Roger Voss     @vossroger
# 2    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
# 3  Lake Michigan Shore               None  Alexander Peartree           None
# 4    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery  year   type
# 0              Nicosia  2013  white
# 1  Quinta dos Avidagos  2011    red
# 2            Rainstorm  2013  white
# 3           St. Julian  2013  white
# 4         Sweet Cheeks  2012    red

# %%
# Print summary info for all columns in revised dataframe.
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   wine_no         129971 non-null  int64
#  1   country         129908 non-null  object
#  2   description     129971 non-null  object
#  3   designation     92506 non-null   object
#  4   points          129971 non-null  int64
#  5   price           120975 non-null  float64
#  6   province        129908 non-null  object
#  7   region_1        108724 non-null  object
#  8   region_2        50511 non-null   object
#  9   taster_name     103727 non-null  object
#  10  taster_twitter  98758 non-null   object
#  11  title           129971 non-null  object
#  12  variety         129970 non-null  object
#  13  winery          129971 non-null  object
#  14  year            123626 non-null  object
#  15  type            124189 non-null  object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 15.9+ MB

# %%
# Check counts for new type column.
wine_df['type'].value_counts()
# Out:
# red      80040
# white    44149
# Name: type, dtype: int64

# %%
# Locate rows that contain null values for type.
null_type = wine_df['type'].isna()
wine_df.loc[null_type,:]
# Out:
#         wine_no    country                                        description  \
# 20           19         US  Red fruit aromas pervade on the nose, with cig...
# 84           83  Australia  Pale copper in hue, this wine exudes passion f...
# 90           89      Italy  Made primarily from Sangiovese, with some Malv...
# 93           92         US  All red Bordeaux varieties are represented in ...
# 178         175      Italy  Crisp and fresh with enduring aromas of tomato...
# ...         ...        ...                                                ...
# 129760   129759     France  Soft and ripe, it is gently fruity with light ...
# 129762   129761     France  Close to the beach of Pampelonne, this is a an...
# 129770   129769         US  The use of 100% Syrah gives a deep pink color ...
# 129776   129775         US  Picturesque with a crystalline salmon color, i...
# 129786   129785         US  This round, fruity and smooth-drinking Sémillo...
#
#                                         designation  points  price  \
# 20                                             None      87   32.0
# 84                                Jester Sangiovese      86   20.0
# 90                                             None      88   19.0
# 93                                       Magnificat      88   55.0
# 178                                        De Silva      88   25.0
# ...                                             ...     ...    ...
# 129760                                      Cuvée G      87    NaN
# 129762                                         None      87   18.0
# 129770                                        Linus      87   22.0
# 129776  Dianthus Estate Mourvèdre-Grenache-Counoise      87   27.0
# 129786                                         None      89   28.0
#
#                   province              region_1         region_2  \
# 20                Virginia              Virginia             None
# 84         South Australia          McLaren Vale             None
# 90                 Tuscany               Toscana             None
# 93              California           Napa Valley             Napa
# 178     Northeastern Italy            Alto Adige             None
# ...                    ...                   ...              ...
# 129760            Provence     Côtes de Provence             None
# 129762            Provence     Côtes de Provence             None
# 129770          California     Santa Ynez Valley    Central Coast
# 129776          California           Paso Robles    Central Coast
# 129786          Washington  Columbia Valley (WA)  Columbia Valley
#
#                taster_name taster_twitter  \
# 20      Alexander Peartree           None
# 84          Joe Czerwinski         @JoeCz
# 90           Kerin O’Keefe   @kerinokeefe
# 93          Virginie Boone        @vboone
# 178                   None           None
# ...                    ...            ...
# 129760          Roger Voss     @vossroger
# 129762          Roger Voss     @vossroger
# 129770       Matt Kettmann  @mattkettmann
# 129776       Matt Kettmann  @mattkettmann
# 129786        Paul Gregutt    @paulgwine
#
#                                                     title    variety  \
# 20                   Quiévremont 2012 Meritage (Virginia)   Meritage
# 84      Mitolo 2016 Jester Sangiovese Rosé (McLaren Vale)       Rosé
# 90                   Fattoria Sardi 2015 Rosato (Toscana)     Rosato
# 93      Franciscan 2013 Magnificat Meritage (Napa Valley)   Meritage
# 178     Tenuta Peter Sölva & Söhne 2007 De Silva Sauvi...  Sauvignon
# ...                                                   ...        ...
# 129760  Les Vignobles Gueissard 2013 Cuvée G Rosé (Côt...       Rosé
# 129762    Mas de Pampelonne 2013 Rosé (Côtes de Provence)       Rosé
# 129770       Solminer 2013 Linus Rosé (Santa Ynez Valley)       Rosé
# 129776  Tablas Creek 2013 Dianthus Estate Mourvèdre-Gr...       Rosé
# 129786     DiStefano 2011 Sémillon (Columbia Valley (WA))   Sémillon
#
#                             winery  year type
# 20                     Quiévremont  2012  NaN
# 84                          Mitolo  2016  NaN
# 90                  Fattoria Sardi  2015  NaN
# 93                      Franciscan  2013  NaN
# 178     Tenuta Peter Sölva & Söhne  2007  NaN
# ...                            ...   ...  ...
# 129760     Les Vignobles Gueissard  2013  NaN
# 129762           Mas de Pampelonne  2013  NaN
# 129770                    Solminer  2013  NaN
# 129776                Tablas Creek  2013  NaN
# 129786                   DiStefano  2011  NaN
#
# [5782 rows x 16 columns]

# %%
# STEP 2 - Call function again to look in title column for dictionary key
# and return red or white value to fill nulls in type column.
wine_df['type'].fillna(wine_df["title"].map(lambda feature: fill_type(feature)), inplace=True)
wine_df.head()
# Out:
#    wine_no   country                                        description  \
# 0        0     Italy  Aromas include tropical fruit, broom, brimston...
# 1        1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        2        US  Tart and snappy, the flavors of lime flesh and...
# 3        3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                None      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name taster_twitter  \
# 0                 Etna               None       Kerin O’Keefe   @kerinokeefe
# 1                 None               None          Roger Voss     @vossroger
# 2    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
# 3  Lake Michigan Shore               None  Alexander Peartree           None
# 4    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery  year   type
# 0              Nicosia  2013  white
# 1  Quinta dos Avidagos  2011    red
# 2            Rainstorm  2013  white
# 3           St. Julian  2013  white
# 4         Sweet Cheeks  2012    red

# %%
# Check counts again for type column.
wine_df['type'].value_counts()
# Out:
# red      80935
# white    44325
# Name: type, dtype: int64

# %%
# Locate rows that contain null values for type.
null_type = wine_df['type'].isna()
wine_df.loc[null_type,:]
# Out:
#         wine_no country                                        description  \
# 20           19      US  Red fruit aromas pervade on the nose, with cig...
# 90           89   Italy  Made primarily from Sangiovese, with some Malv...
# 93           92      US  All red Bordeaux varieties are represented in ...
# 178         175   Italy  Crisp and fresh with enduring aromas of tomato...
# 274         271  Greece  Lively aromas of lemon, grapefruit and melon s...
# ...         ...     ...                                                ...
# 129759   129758  France  This is a barely pink rosé, perfect to reflect...
# 129760   129759  France  Soft and ripe, it is gently fruity with light ...
# 129762   129761  France  Close to the beach of Pampelonne, this is a an...
# 129770   129769      US  The use of 100% Syrah gives a deep pink color ...
# 129786   129785      US  This round, fruity and smooth-drinking Sémillo...
#
#                        designation  points  price            province  \
# 20                            None      87   32.0            Virginia
# 90                            None      88   19.0             Tuscany
# 93                      Magnificat      88   55.0          California
# 178                       De Silva      88   25.0  Northeastern Italy
# 274                           None      89   15.0           Santorini
# ...                            ...     ...    ...                 ...
# 129759  Les Voiles de Saint-Tropez      87    NaN            Provence
# 129760                     Cuvée G      87    NaN            Provence
# 129762                        None      87   18.0            Provence
# 129770                       Linus      87   22.0          California
# 129786                        None      89   28.0          Washington
#
#                     region_1         region_2         taster_name  \
# 20                  Virginia             None  Alexander Peartree
# 90                   Toscana             None       Kerin O’Keefe
# 93               Napa Valley             Napa      Virginie Boone
# 178               Alto Adige             None                None
# 274                     None             None     Susan Kostrzewa
# ...                      ...              ...                 ...
# 129759     Côtes de Provence             None          Roger Voss
# 129760     Côtes de Provence             None          Roger Voss
# 129762     Côtes de Provence             None          Roger Voss
# 129770     Santa Ynez Valley    Central Coast       Matt Kettmann
# 129786  Columbia Valley (WA)  Columbia Valley        Paul Gregutt
#
#        taster_twitter                                              title  \
# 20               None               Quiévremont 2012 Meritage (Virginia)
# 90       @kerinokeefe               Fattoria Sardi 2015 Rosato (Toscana)
# 93            @vboone  Franciscan 2013 Magnificat Meritage (Napa Valley)
# 178              None  Tenuta Peter Sölva & Söhne 2007 De Silva Sauvi...
# 274     @suskostrzewa   My Big Fat Greek Wine 2010 Assyrtico (Santorini)
# ...               ...                                                ...
# 129759     @vossroger  Les Maîtres Vignerons de la Presqu'île de Sain...
# 129760     @vossroger  Les Vignobles Gueissard 2013 Cuvée G Rosé (Côt...
# 129762     @vossroger    Mas de Pampelonne 2013 Rosé (Côtes de Provence)
# 129770  @mattkettmann       Solminer 2013 Linus Rosé (Santa Ynez Valley)
# 129786    @paulgwine      DiStefano 2011 Sémillon (Columbia Valley (WA))
#
#           variety                                             winery  year  \
# 20       Meritage                                        Quiévremont  2012
# 90         Rosato                                     Fattoria Sardi  2015
# 93       Meritage                                         Franciscan  2013
# 178     Sauvignon                         Tenuta Peter Sölva & Söhne  2007
# 274     Assyrtico                              My Big Fat Greek Wine  2010
# ...           ...                                                ...   ...
# 129759       Rosé  Les Maîtres Vignerons de la Presqu'île de Sain...  2013
# 129760       Rosé                            Les Vignobles Gueissard  2013
# 129762       Rosé                                  Mas de Pampelonne  2013
# 129770       Rosé                                           Solminer  2013
# 129786   Sémillon                                          DiStefano  2011
#
#        type
# 20      NaN
# 90      NaN
# 93      NaN
# 178     NaN
# 274     NaN
# ...     ...
# 129759  NaN
# 129760  NaN
# 129762  NaN
# 129770  NaN
# 129786  NaN
#
# [4711 rows x 16 columns]

# %%
# STEP 3 - Call function again to look in description column for dictionary key 
# and return red or white value to fill nulls in type column.
wine_df['type'].fillna(wine_df["description"].map(lambda feature: fill_type(feature)), inplace=True)
wine_df.head()
# Out:
#    wine_no   country                                        description  \
# 0        0     Italy  Aromas include tropical fruit, broom, brimston...
# 1        1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        2        US  Tart and snappy, the flavors of lime flesh and...
# 3        3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                None      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name taster_twitter  \
# 0                 Etna               None       Kerin O’Keefe   @kerinokeefe
# 1                 None               None          Roger Voss     @vossroger
# 2    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
# 3  Lake Michigan Shore               None  Alexander Peartree           None
# 4    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery  year   type
# 0              Nicosia  2013  white
# 1  Quinta dos Avidagos  2011    red
# 2            Rainstorm  2013  white
# 3           St. Julian  2013  white
# 4         Sweet Cheeks  2012    red

# %%
# Check counts again for type column.
wine_df['type'].value_counts()
# Out:
# red      84597
# white    45023
# Name: type, dtype: int64

# %%
# Locate rows that contain null values for type.
null_type = wine_df['type'].isna()
wine_df.loc[null_type,:]
# Out:
#         wine_no   country                                        description  \
# 562         554    France  Named after the Negrel family, owners of the e...
# 1136       1121    France  This wine came out of the disaster of shrivele...
# 1282       1268     Italy  Cusumano's fresh Insolia delivers a steady, ne...
# 1540       1526     Italy  Aromas of acacia, mature apple, hazelnut and a...
# 1649       4939  Portugal  A particularly clean, fresh and dry rosé, full...
# ...         ...       ...                                                ...
# 128562   128559        US  Aromas of violets and cherries are intoxicatin...
# 128612   128608    France  While this wine has high acidity, it also offe...
# 129081   129076   Hungary  This off-dry, honeyed Tokaj wine has a penetra...
# 129086   129081     Italy  This wine opens with forest fruit, chopped her...
# 129188   129188    France  Made in a more savory style, this shows hints ...
#
#                designation  points  price           province  \
# 562     Mas Negrel Cadenet      93   40.0           Provence
# 1136          Noces de Feu      90    NaN       France Other
# 1282                  None      85   12.0  Sicily & Sardinia
# 1540                 Hierà      86   21.0  Sicily & Sardinia
# 1649                  None      86   18.0             Lisboa
# ...                    ...     ...    ...                ...
# 128562                None      89   23.0           New York
# 128612                None      85   13.0           Bordeaux
# 129081    3 Puttonyos Aszú      87   20.0             Tokaji
# 129086              Agoghè      87   18.0            Tuscany
# 129188                None      84   13.0       Rhône Valley
#
#                                  region_1      region_2         taster_name  \
# 562     Côtes de Provence Sainte-Victoire          None          Roger Voss
# 1136                       Vin de Liqueur          None          Roger Voss
# 1282                              Sicilia          None                None
# 1540                      Terre Siciliane          None       Kerin O’Keefe
# 1649                                 None          None          Roger Voss
# ...                                   ...           ...                 ...
# 128562                       Finger Lakes  Finger Lakes  Anna Lee C. Iijima
# 128612                      Bordeaux Rosé          None          Roger Voss
# 129081                               None          None  Anna Lee C. Iijima
# 129086                            Toscana          None                None
# 129188                     Côtes du Rhône          None      Joe Czerwinski
#
#        taster_twitter                                              title  \
# 562        @vossroger  Mas de Cadenet 2015 Mas Negrel Cadenet Rosé (C...
# 1136       @vossroger  Domaine Rotier NV Noces de Feu Duras (Vin de L...
# 1282             None                    Cusumano 2010 Insolia (Sicilia)
# 1540     @kerinokeefe           Hauner 2015 Hierà Rosé (Terre Siciliane)
# 1649       @vossroger              Quinta de Sant'Ana 2010 Rosé (Lisboa)
# ...               ...                                                ...
# 128562           None                 Knapp 2011 Meritage (Finger Lakes)
# 128612     @vossroger        Château d'Haurets 2016 Rosé (Bordeaux Rosé)
# 129081           None     Château Hellha 2002 3 Puttonyos Aszú  (Tokaji)
# 129086           None    Donna Olimpia 1898 2011 Agoghè Rosato (Toscana)
# 129188         @JoeCz           Louis Bernard 2016 Rosé (Côtes du Rhône)
#
#          variety              winery  year type
# 562         Rosé      Mas de Cadenet  2015  NaN
# 1136       Duras      Domaine Rotier   NaN  NaN
# 1282     Insolia            Cusumano  2010  NaN
# 1540        Rosé              Hauner  2015  NaN
# 1649        Rosé  Quinta de Sant'Ana  2010  NaN
# ...          ...                 ...   ...  ...
# 128562  Meritage               Knapp  2011  NaN
# 128612      Rosé   Château d'Haurets  2016  NaN
# 129081    Tokaji      Château Hellha  2002  NaN
# 129086    Rosato  Donna Olimpia 1898  2011  NaN
# 129188      Rosé       Louis Bernard  2016  NaN
#
# [351 rows x 16 columns]

# %% [markdown]
# ## Add column to group ratings (points) into 5 categories

# %% [markdown]
# ### the rating_category feature will help give context for our dasboard but we are not using it to train the machine learning model since it's derived from the feature we are trying to predict.

# %%
rating_category = []
for row in wine_df['points']:
    if row < 84: rating_category.append('below average')
    elif row < 88: rating_category.append('average')
    elif row < 92: rating_category.append('good')
    elif row < 96: rating_category.append('very good')  
    elif row <= 100: rating_category.append('excellent')
        
    else: rating.append('not rated')
    
wine_df['points_category'] = rating_category
wine_df.head()
# Out:
#    wine_no   country                                        description  \
# 0        0     Italy  Aromas include tropical fruit, broom, brimston...
# 1        1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        2        US  Tart and snappy, the flavors of lime flesh and...
# 3        3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                None      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name taster_twitter  \
# 0                 Etna               None       Kerin O’Keefe   @kerinokeefe
# 1                 None               None          Roger Voss     @vossroger
# 2    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
# 3  Lake Michigan Shore               None  Alexander Peartree           None
# 4    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery  year   type points_category
# 0              Nicosia  2013  white         average
# 1  Quinta dos Avidagos  2011    red         average
# 2            Rainstorm  2013  white         average
# 3           St. Julian  2013  white         average
# 4         Sweet Cheeks  2012    red         average

# %%
wine_df['points_category'].value_counts()
# Out:
# good             56202
# average          45543
# very good        21395
# below average     5950
# excellent          881
# Name: points_category, dtype: int64

# %% [markdown]
# ## Replace null values for region_1

# %%
# Replace null values in region_1 column with province name.
wine_df['region_1'].fillna(wine_df['province'], inplace=True) 
wine_df.head()
# Out:
#    wine_no   country                                        description  \
# 0        0     Italy  Aromas include tropical fruit, broom, brimston...
# 1        1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        2        US  Tart and snappy, the flavors of lime flesh and...
# 3        3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                None      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name taster_twitter  \
# 0                 Etna               None       Kerin O’Keefe   @kerinokeefe
# 1                Douro               None          Roger Voss     @vossroger
# 2    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
# 3  Lake Michigan Shore               None  Alexander Peartree           None
# 4    Willamette Valley  Willamette Valley        Paul Gregutt    @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery  year   type points_category
# 0              Nicosia  2013  white         average
# 1  Quinta dos Avidagos  2011    red         average
# 2            Rainstorm  2013  white         average
# 3           St. Julian  2013  white         average
# 4         Sweet Cheeks  2012    red         average

# %%
# Print summary info for all columns in revised dataframe.
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   wine_no          129971 non-null  int64
#  1   country          129908 non-null  object
#  2   description      129971 non-null  object
#  3   designation      92506 non-null   object
#  4   points           129971 non-null  int64
#  5   price            120975 non-null  float64
#  6   province         129908 non-null  object
#  7   region_1         129908 non-null  object
#  8   region_2         50511 non-null   object
#  9   taster_name      103727 non-null  object
#  10  taster_twitter   98758 non-null   object
#  11  title            129971 non-null  object
#  12  variety          129970 non-null  object
#  13  winery           129971 non-null  object
#  14  year             123626 non-null  object
#  15  type             129620 non-null  object
#  16  points_category  129971 non-null  object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 16.9+ MB

# %% [markdown]
# ## Replace null values in taster_name to unknown

# %%
# Locate rows that contain null values for taster_name.
null_tasters = wine_df['taster_name'].isna()
wine_df.loc[null_tasters,:]
# Out:
#         wine_no country                                        description  \
# 19        60865      US  Soft and simple, with candied fruit, cola and ...
# 32           31   Italy  Merlot and Nero d'Avola form the base for this...
# 33           32   Italy  Part of the extended Calanìca series, this Gri...
# 34           33      US  Rustic and dry, this has flavors of berries, c...
# 35           34      US  This shows a tart, green gooseberry flavor tha...
# ...         ...     ...                                                ...
# 129852   129852   Italy  Here's an easy blend of Cabernet Sauvignon and...
# 129914   129914      US  Fritz has made tremendous progress with Cab ov...
# 129920   129920      US  Shows the clean, citrus acid juiciness and sil...
# 129929   129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129940   129940      US  This is the winery's bells and whistles Chardo...
#
#                          designation  points  price           province  \
# 19                              None      82    8.0         California
# 32      Calanìca Nero d'Avola-Merlot      86    NaN  Sicily & Sardinia
# 33          Calanìca Grillo-Viognier      86    NaN  Sicily & Sardinia
# 34             Puma Springs Vineyard      86   50.0         California
# 35                              None      86   20.0         California
# ...                              ...     ...    ...                ...
# 129852                          None      86   10.0  Sicily & Sardinia
# 129914                          None      91   35.0         California
# 129920           Fiddlestix Vineyard      91   48.0         California
# 129929                          None      91   38.0             Veneto
# 129940               Watson Vineyard      91   36.0         California
#
#                               region_1          region_2 taster_name  \
# 19                          California  California Other        None
# 32                             Sicilia              None        None
# 33                             Sicilia              None        None
# 34                    Dry Creek Valley            Sonoma        None
# 35                       Sonoma Valley            Sonoma        None
# ...                                ...               ...         ...
# 129852                         Sicilia              None        None
# 129914                Dry Creek Valley            Sonoma        None
# 129920                 Sta. Rita Hills     Central Coast        None
# 129929  Prosecco Superiore di Cartizze              None        None
# 129940                       Mendocino              None        None
#
#        taster_twitter                                              title  \
# 19               None             Redtree 2009 Petite Sirah (California)
# 32               None  Duca di Salaparuta 2010 Calanìca Nero d'Avola-...
# 33               None  Duca di Salaparuta 2011 Calanìca Grillo-Viogni...
# 34               None  Envolve 2010 Puma Springs Vineyard Red (Dry Cr...
# 35               None       Envolve 2011 Sauvignon Blanc (Sonoma Valley)
# ...               ...                                                ...
# 129852           None  MandraRossa 2006 Cabernet Sauvignon-Shiraz (Si...
# 129914           None   Fritz 2005 Cabernet Sauvignon (Dry Creek Valley)
# 129920           None  Pali 2006 Fiddlestix Vineyard Pinot Noir (Sta....
# 129929           None  Col Vetoraz Spumanti NV  Prosecco Superiore di...
# 129940           None  Standish 2006 Watson Vineyard Chardonnay (Mend...
#
#                           variety                winery  year   type  \
# 19                   Petite Sirah               Redtree  2009    red
# 32                      Red Blend    Duca di Salaparuta  2010    red
# 33                    White Blend    Duca di Salaparuta  2011  white
# 34                      Red Blend               Envolve  2010    red
# 35                Sauvignon Blanc               Envolve  2011  white
# ...                           ...                   ...   ...    ...
# 129852  Cabernet Sauvignon-Shiraz           MandraRossa  2006    red
# 129914         Cabernet Sauvignon                 Fritz  2005    red
# 129920                 Pinot Noir                  Pali  2006    red
# 129929                   Prosecco  Col Vetoraz Spumanti   NaN  white
# 129940                 Chardonnay              Standish  2006  white
#
#        points_category
# 19       below average
# 32             average
# 33             average
# 34             average
# 35             average
# ...                ...
# 129852         average
# 129914            good
# 129920            good
# 129929            good
# 129940            good
#
# [26244 rows x 17 columns]

# %%
# Replace null values in taster_name column with unknowns.
wine_df['taster_name'].fillna('unknown', inplace=True)
wine_df[30:40]
# Out:
#     wine_no country                                        description  \
# 30       29      US  Clarksburg is becoming a haven for Chenin Blan...
# 31       30  France  Red cherry fruit comes laced with light tannin...
# 32       31   Italy  Merlot and Nero d'Avola form the base for this...
# 33       32   Italy  Part of the extended Calanìca series, this Gri...
# 34       33      US  Rustic and dry, this has flavors of berries, c...
# 35       34      US  This shows a tart, green gooseberry flavor tha...
# 36       35      US  As with many of the Erath 2010 vineyard design...
# 37       36   Chile  White flower, lychee and apple aromas carry th...
# 38       37   Italy  This concentrated Cabernet offers aromas of cu...
# 39       38   Italy  Inky in color, this wine has plump aromas of r...
#
#                      designation  points  price           province  \
# 30                          None      86   16.0         California
# 31                       Nouveau      86    NaN         Beaujolais
# 32  Calanìca Nero d'Avola-Merlot      86    NaN  Sicily & Sardinia
# 33      Calanìca Grillo-Viognier      86    NaN  Sicily & Sardinia
# 34         Puma Springs Vineyard      86   50.0         California
# 35                          None      86   20.0         California
# 36                        Hyland      86   50.0             Oregon
# 37                        Estate      86   15.0   Colchagua Valley
# 38                       Missoni      86   21.0  Sicily & Sardinia
# 39                    I Tratturi      86   11.0     Southern Italy
#
#                region_1           region_2        taster_name taster_twitter  \
# 30           Clarksburg     Central Valley     Virginie Boone        @vboone
# 31  Beaujolais-Villages               None         Roger Voss     @vossroger
# 32              Sicilia               None            unknown           None
# 33              Sicilia               None            unknown           None
# 34     Dry Creek Valley             Sonoma            unknown           None
# 35        Sonoma Valley             Sonoma            unknown           None
# 36          McMinnville  Willamette Valley       Paul Gregutt    @paulgwine
# 37     Colchagua Valley               None  Michael Schachner    @wineschach
# 38              Sicilia               None            unknown           None
# 39               Puglia               None            unknown           None
#
#                                                 title              variety  \
# 30  Clarksburg Wine Company 2010 Chenin Blanc (Cla...         Chenin Blanc
# 31  Domaine de la Madone 2012 Nouveau  (Beaujolais...                Gamay
# 32  Duca di Salaparuta 2010 Calanìca Nero d'Avola-...            Red Blend
# 33  Duca di Salaparuta 2011 Calanìca Grillo-Viogni...          White Blend
# 34  Envolve 2010 Puma Springs Vineyard Red (Dry Cr...            Red Blend
# 35       Envolve 2011 Sauvignon Blanc (Sonoma Valley)      Sauvignon Blanc
# 36         Erath 2010 Hyland Pinot Noir (McMinnville)           Pinot Noir
# 37  Estampa 2011 Estate Viognier-Chardonnay (Colch...  Viognier-Chardonnay
# 38  Feudi del Pisciotto 2010 Missoni Cabernet Sauv...   Cabernet Sauvignon
# 39  Feudi di San Marzano 2011 I Tratturi Primitivo...            Primitivo
#
#                      winery  year   type points_category
# 30  Clarksburg Wine Company  2010  white         average
# 31     Domaine de la Madone  2012    red         average
# 32       Duca di Salaparuta  2010    red         average
# 33       Duca di Salaparuta  2011  white         average
# 34                  Envolve  2010    red         average
# 35                  Envolve  2011  white         average
# 36                    Erath  2010    red         average
# 37                  Estampa  2011  white         average
# 38      Feudi del Pisciotto  2010    red         average
# 39     Feudi di San Marzano  2011    red         average

# %%
# Print list of unique taste testers.
wine_df['taster_name'].value_counts()
# Out:
# unknown               26244
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
# Print summary info for all columns in revised dataframe.
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   wine_no          129971 non-null  int64
#  1   country          129908 non-null  object
#  2   description      129971 non-null  object
#  3   designation      92506 non-null   object
#  4   points           129971 non-null  int64
#  5   price            120975 non-null  float64
#  6   province         129908 non-null  object
#  7   region_1         129908 non-null  object
#  8   region_2         50511 non-null   object
#  9   taster_name      129971 non-null  object
#  10  taster_twitter   98758 non-null   object
#  11  title            129971 non-null  object
#  12  variety          129970 non-null  object
#  13  winery           129971 non-null  object
#  14  year             123626 non-null  object
#  15  type             129620 non-null  object
#  16  points_category  129971 non-null  object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 16.9+ MB

# %% [markdown]
# ## Create new wine_df

# %%
# Create new dataframe with only the columns to keep. 
# (drop columns for description, designation, region_2, and taster_twitter_handle)

selected_columns = ['country', 'points', 'price', 'province','region_1', 'taster_name',
                    'title', 'variety', 'winery', 'year', 'type', 'points_category']

wine_df = wine_df[selected_columns]
wine_df.head()
# Out:
#     country  points  price           province             region_1  \
# 0     Italy      87    NaN  Sicily & Sardinia                 Etna
# 1  Portugal      87   15.0              Douro                Douro
# 2        US      87   14.0             Oregon    Willamette Valley
# 3        US      87   13.0           Michigan  Lake Michigan Shore
# 4        US      87   65.0             Oregon    Willamette Valley
#
#           taster_name                                              title  \
# 0       Kerin O’Keefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1          Roger Voss      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        Paul Gregutt      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3  Alexander Peartree  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        Paul Gregutt  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery  year   type points_category
# 0     White Blend              Nicosia  2013  white         average
# 1  Portuguese Red  Quinta dos Avidagos  2011    red         average
# 2      Pinot Gris            Rainstorm  2013  white         average
# 3        Riesling           St. Julian  2013  white         average
# 4      Pinot Noir         Sweet Cheeks  2012    red         average

# %%
# Create function to display info for null values in dataframe.
def missing_values_table(df):
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    return mis_val_table_ren_columns

# %%
# Call function to display null values in dataframe.
missing_values_table(wine_df)
# Out:
# Your selected dataframe has 12 columns.
# There are 7 columns that have missing values.
#           Missing Values  % of Total Values
# price               8996                6.9
# year                6345                4.9
# type                 351                0.3
# country               63                0.0
# province              63                0.0
# region_1              63                0.0
# variety                1                0.0

# %%
# Drop all rows with null values and renumber index.
wine_df = wine_df.dropna().reset_index(drop=True)
wine_df.head()
# Out:
#     country  points  price        province             region_1  \
# 0  Portugal      87   15.0           Douro                Douro
# 1        US      87   14.0          Oregon    Willamette Valley
# 2        US      87   13.0        Michigan  Lake Michigan Shore
# 3        US      87   65.0          Oregon    Willamette Valley
# 4     Spain      87   15.0  Northern Spain              Navarra
#
#           taster_name                                              title  \
# 0          Roger Voss      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1        Paul Gregutt      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2  Alexander Peartree  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3        Paul Gregutt  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4   Michael Schachner  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery  year   type points_category
# 0      Portuguese Red  Quinta dos Avidagos  2011    red         average
# 1          Pinot Gris            Rainstorm  2013  white         average
# 2            Riesling           St. Julian  2013  white         average
# 3          Pinot Noir         Sweet Cheeks  2012    red         average
# 4  Tempranillo-Merlot               Tandem  2011    red         average

# %%
# Print summary info for all columns in cleaned and transformed dataframe.
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114829 entries, 0 to 114828
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   country          114829 non-null  object
#  1   points           114829 non-null  int64
#  2   price            114829 non-null  float64
#  3   province         114829 non-null  object
#  4   region_1         114829 non-null  object
#  5   taster_name      114829 non-null  object
#  6   title            114829 non-null  object
#  7   variety          114829 non-null  object
#  8   winery           114829 non-null  object
#  9   year             114829 non-null  object
#  10  type             114829 non-null  object
#  11  points_category  114829 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 10.5+ MB

# %%
# Save final cleaned and transformed wine_df as CSV file.
wine_df.to_csv('clean_wine_data.csv', index=False)

# %% [markdown]
# # Analysis Phase

# %%
# Check simple stats for dataset.
wine_df.describe()
# Out:
#               points          price
# count  114829.000000  114829.000000
# mean       88.467486      35.418866
# std         3.034933      40.849751
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %% [markdown]
# ## Questions about year

# %%
# Print counts of wines by year produced.
wine_df['year'].value_counts()
# Out:
# 2013    15162
# 2014    14840
# 2012    14719
# 2011    11411
# 2010    11083
# 2015     9584
# 2009     9043
# 2008     6715
# 2007     6476
# 2006     5162
# 2016     3508
# 2005     3289
# 2004     1602
# 2000      730
# 2001      666
# 2003      498
# 2002      330
# 2017       11
# Name: year, dtype: int64

# %%
# Print number of wines for each year, sorted from newer to older.
wine_df['year'].value_counts().sort_index(ascending=False)
# Out:
# 2017       11
# 2016     3508
# 2015     9584
# 2014    14840
# 2013    15162
# 2012    14719
# 2011    11411
# 2010    11083
# 2009     9043
# 2008     6715
# 2007     6476
# 2006     5162
# 2005     3289
# 2004     1602
# 2003      498
# 2002      330
# 2001      666
# 2000      730
# Name: year, dtype: int64

# %% [markdown]
# ### Is there a year that stands out as the best?

# %%
# Highest price by year
wine_df.groupby(['year']).mean().sort_values('price', ascending=False).head(10)
# Out:
#          points      price
# year
# 2003  88.367470  50.817269
# 2004  88.712859  48.375780
# 2005  88.244755  42.481301
# 2009  88.276678  38.537322
# 2006  88.082720  38.501744
# 2002  87.572727  38.484848
# 2008  88.127178  37.616381
# 2007  88.090488  37.535825
# 2010  88.195705  37.236308
# 2012  88.761533  36.802636

# %%
# Highest ratings by year
wine_df.groupby(['year']).mean().sort_values('points', ascending=False).head(10)
# Out:
#          points      price
# year
# 2013  88.979027  36.438135
# 2014  88.894744  33.656334
# 2012  88.761533  36.802636
# 2004  88.712859  48.375780
# 2015  88.533598  25.418927
# 2003  88.367470  50.817269
# 2009  88.276678  38.537322
# 2005  88.244755  42.481301
# 2011  88.242748  36.024187
# 2010  88.195705  37.236308

# %% [markdown]
# ## Questions about variety

# %% [markdown]
# ### What are the most popular varieties?

# %%
# Show top 10 grape varieties.
pop_varieties_count = wine_df['variety'].value_counts().nlargest(10)
pop_varieties_count
# Out:
# Pinot Noir                  12479
# Chardonnay                  10660
# Cabernet Sauvignon           9092
# Red Blend                    8190
# Bordeaux-style Red Blend     5276
# Riesling                     4927
# Sauvignon Blanc              4742
# Syrah                        4035
# Rosé                         3096
# Merlot                       2925
# Name: variety, dtype: int64

# %% [markdown]
# ### What are the average ratings and price for popular varieties?

# %%
# Show top 10 grape varieties and their average rating and average price.
list(pop_varieties_count.index)

# Calculate average points and price for all varieties.
pop_varieties_rating = wine_df.groupby(['variety']).mean()
pop_varieties_rating['variety'] = pop_varieties_rating.index
 
def filterbylist(filterlist):
    # instantiated our filtered_df using the first string in our filterlist
    filtered_df = pop_varieties_rating[pop_varieties_rating['variety']==filterlist[0]]
    
    # adds all other varieties to the filtered_df, 1 at a time
    for grape_variety in filterlist[1:]:
        loop_df = pop_varieties_rating[pop_varieties_rating['variety']==grape_variety]
        filtered_df = pd.concat([filtered_df, loop_df])
    return filtered_df

filterbylist(list(pop_varieties_count.index)).drop(['variety'], axis=1)
# Out:
#                              points      price
# variety
# Pinot Noir                89.443545  47.894944
# Chardonnay                88.300000  34.198968
# Cabernet Sauvignon        88.623295  48.175869
# Red Blend                 88.460562  36.257753
# Bordeaux-style Red Blend  88.798901  47.242229
# Riesling                  89.454435  32.043231
# Sauvignon Blanc           87.417334  20.237242
# Syrah                     89.308302  39.316233
# Rosé                      86.931525  18.380168
# Merlot                    87.235214  29.920000

# %% [markdown]
# ### What varieties earn the highest rating?

# %%
# Show top 10 grape varieties by highest average rating, along with average price. 
wine_df.groupby(['variety']).mean().sort_values('points', ascending=False).head(10)
# Out:
#                      points  price
# variety
# Tinta del Pais         95.0   47.5
# Gelber Traminer        95.0   35.0
# Sercial                94.0   50.0
# Riesling-Chardonnay    94.0   40.0
# Roviello               93.0   28.0
# Bual                   93.0   38.0
# Blauburgunder          93.0   19.0
# Garnacha-Cariñena      93.0   57.0
# Sirica                 92.5   23.0
# Torontel               92.0   40.0

# %% [markdown]
# ## Questions about rating and rating category

# %%
# Print ratings by number of times they appear in dataset and sort from highest to lowest. 
wine_df['points'].value_counts().sort_index(ascending=False)
# Out:
# 100       17
# 99        26
# 98        65
# 97       196
# 96       463
# 95      1359
# 94      3349
# 93      5742
# 92      8576
# 91     10191
# 90     13762
# 89     10760
# 88     15206
# 87     14863
# 86     11059
# 85      8364
# 84      5665
# 83      2618
# 82      1599
# 81       604
# 80       345
# Name: points, dtype: int64

# %%
# Explore distribution of ratings by category.
wine_df['points_category'].value_counts()
# Out:
# good             49919
# average          39951
# very good        19026
# below average     5166
# excellent          767
# Name: points_category, dtype: int64

# %% [markdown]
# ### Is there a relationship between rating and price?

# %%
# Average price for ratings categories.
wine_df.groupby(['points_category']).mean().sort_values('price', ascending=False)
# Out:
#                     points       price
# points_category
# excellent        96.615385  189.714472
# very good        92.868128   63.641596
# good             89.379375   34.527214
# average          85.879077   22.322795
# below average    82.256291   18.462060

# %% [markdown]
# ## Regional Trends. Questions about country and province

# %%
# Print counts of wines by country. 
wine_df['country'].value_counts()
# Out:
# US                        52369
# France                    16100
# Italy                     15841
# Spain                      5976
# Portugal                   4582
# Chile                      4291
# Argentina                  3711
# Austria                    2753
# Australia                  2162
# Germany                    2099
# New Zealand                1362
# South Africa               1235
# Israel                      483
# Greece                      430
# Canada                      245
# Bulgaria                    141
# Hungary                     133
# Romania                     120
# Uruguay                     108
# Turkey                       90
# Georgia                      81
# Slovenia                     78
# Croatia                      70
# Mexico                       66
# Moldova                      57
# England                      55
# Brazil                       38
# Lebanon                      34
# Morocco                      28
# Peru                         16
# Serbia                       12
# Macedonia                    12
# Czech Republic               11
# Cyprus                       10
# India                         9
# Switzerland                   7
# Ukraine                       5
# Luxembourg                    3
# Armenia                       2
# Bosnia and Herzegovina        2
# China                         1
# Slovakia                      1
# Name: country, dtype: int64

# %%
# Print top 10 provinces that show up most often in dataset.
wine_df['province'].value_counts().head(10)
# Out:
# California          34793
# Washington           8425
# Oregon               5185
# Tuscany              4997
# Bordeaux             3963
# Northern Spain       3727
# Mendoza Province     3187
# Piedmont             3047
# Burgundy             3039
# New York             2556
# Name: province, dtype: int64

# %% [markdown]
# ### What is the average rating and price by country?

# %%
# Show mean of rating and price broken down by country.
wine_df.groupby(['country']).mean()
# Out:
#                            points      price
# country
# Argentina               86.739962  24.588251
# Armenia                 87.500000  14.500000
# Australia               88.634598  35.311286
# Austria                 90.220487  30.718852
# Bosnia and Herzegovina  86.500000  12.500000
# Brazil                  84.394737  23.631579
# Bulgaria                87.936170  14.645390
# Canada                  89.440816  35.424490
# Chile                   86.534607  20.840364
# China                   89.000000  18.000000
# Croatia                 87.300000  25.100000
# Cyprus                  87.000000  16.200000
# Czech Republic          87.454545  24.818182
# England                 91.709091  52.400000
# France                  88.743665  40.250807
# Georgia                 87.703704  19.246914
# Germany                 89.841829  42.396856
# Greece                  87.355814  22.546512
# Hungary                 89.172932  39.218045
# India                   90.222222  13.333333
# Israel                  88.559006  32.000000
# Italy                   88.726596  40.667950
# Lebanon                 87.764706  30.117647
# Luxembourg              88.666667  22.666667
# Macedonia               86.833333  15.583333
# Mexico                  85.272727  27.363636
# Moldova                 87.280702  16.929825
# Morocco                 88.571429  19.500000
# New Zealand             88.316446  26.964023
# Peru                    83.562500  18.062500
# Portugal                88.293103  23.718245
# Romania                 86.400000  15.241667
# Serbia                  87.500000  24.500000
# Slovakia                87.000000  16.000000
# Slovenia                88.038462  24.525641
# South Africa            87.903644  24.842915
# Spain                   87.347557  28.697959
# Switzerland             88.571429  85.285714
# Turkey                  88.088889  24.633333
# US                      88.615001  36.915179
# Ukraine                 83.800000   8.800000
# Uruguay                 86.712963  26.444444

# %% [markdown]
# ### Which countries have the best average ratings?

# %%
# Show top 10 countries by highest average rating, along with average price.
wine_df.groupby(['country']).mean().sort_values('points', ascending=False).head(10)
# Out:
#                points      price
# country
# England     91.709091  52.400000
# India       90.222222  13.333333
# Austria     90.220487  30.718852
# Germany     89.841829  42.396856
# Canada      89.440816  35.424490
# Hungary     89.172932  39.218045
# China       89.000000  18.000000
# France      88.743665  40.250807
# Italy       88.726596  40.667950
# Luxembourg  88.666667  22.666667

# %% [markdown]
# ### Which countries have the worst average ratings?

# %%
# Show bottom 10 countries by lowest average rating, along with average price.
wine_df.groupby(['country']).mean().sort_values('points', ascending=True).head(10)
# Out:
#                            points      price
# country
# Peru                    83.562500  18.062500
# Ukraine                 83.800000   8.800000
# Brazil                  84.394737  23.631579
# Mexico                  85.272727  27.363636
# Romania                 86.400000  15.241667
# Bosnia and Herzegovina  86.500000  12.500000
# Chile                   86.534607  20.840364
# Uruguay                 86.712963  26.444444
# Argentina               86.739962  24.588251
# Macedonia               86.833333  15.583333

# %% [markdown]
# ## Question about tasters

# %% [markdown]
# ### How many wines did each taster rate?

# %%
# Print numbers of wines the tasters tested.
wine_df['taster_name'].value_counts()
# Out:
# unknown               22610
# Roger Voss            18552
# Michael Schachner     14168
# Kerin O’Keefe          9538
# Virginie Boone         9396
# Paul Gregutt           9136
# Matt Kettmann          6202
# Sean P. Sullivan       4867
# Joe Czerwinski         4720
# Anna Lee C. Iijima     4276
# Jim Gordon             4008
# Anne Krebiehl MW       3183
# Lauren Buzzeo          1670
# Susan Kostrzewa        1010
# Mike DeSimone           490
# Jeff Jenssen            453
# Alexander Peartree      392
# Carrie Dykes            131
# Fiona Adams              22
# Christina Pickard         5
# Name: taster_name, dtype: int64

# %% [markdown]
# ## Questions about wine type

# %%
# Show number of wine types.
wine_df['type'].value_counts()
# Out:
# red      76632
# white    38197
# Name: type, dtype: int64

# %% [markdown]
# ### What is the average rating and price by type?

# %%
# Average rating and price by wine type.
wine_df.groupby(['type']).mean()
# Out:
#           points     price
# type
# red    88.588018  38.96722
# white  88.225672  28.30005

# %% [markdown]
# ## Prepare for Seaborn analysis

# %%
# Check data types.
wine_df.dtypes
# Out:
# country             object
# points               int64
# price              float64
# province            object
# region_1            object
# taster_name         object
# title               object
# variety             object
# winery              object
# year                object
# type                object
# points_category     object
# dtype: object

# %%
# Convert year data type to integer for pairplot.
wine_df["year"] = wine_df["year"].astype(int)
wine_df.head()
# Out:
#     country  points  price        province             region_1  \
# 0  Portugal      87   15.0           Douro                Douro
# 1        US      87   14.0          Oregon    Willamette Valley
# 2        US      87   13.0        Michigan  Lake Michigan Shore
# 3        US      87   65.0          Oregon    Willamette Valley
# 4     Spain      87   15.0  Northern Spain              Navarra
#
#           taster_name                                              title  \
# 0          Roger Voss      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1        Paul Gregutt      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2  Alexander Peartree  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3        Paul Gregutt  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4   Michael Schachner  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery  year   type points_category
# 0      Portuguese Red  Quinta dos Avidagos  2011    red         average
# 1          Pinot Gris            Rainstorm  2013  white         average
# 2            Riesling           St. Julian  2013  white         average
# 3          Pinot Noir         Sweet Cheeks  2012    red         average
# 4  Tempranillo-Merlot               Tandem  2011    red         average

# %%
# Double check data types again.
wine_df.dtypes
# Out:
# country             object
# points               int64
# price              float64
# province            object
# region_1            object
# taster_name         object
# title               object
# variety             object
# winery              object
# year                 int32
# type                object
# points_category     object
# dtype: object

# %% [markdown]
# ## Visualizations

# %%
# Create pairplot to visualize relationships between price, points, and year features.
sns.pairplot(wine_df)

# %%
# Create bar graph of wine prices by country.
fig = sns.catplot(x='country', 
            y='price', 
            data=wine_df, 
            palette='Set1',
            kind='bar',
            height=4,
            aspect=4)
fig.set_xticklabels(rotation=45, horizontalalignment='right')

# %%
# Create bar graph of wine ratings by country.
sns.catplot(x='points', 
            y='country', 
            data=wine_df, 
            palette='flare',
            kind='bar',
            height=10,
            aspect=1)

# %%
# Create scatter plot to see relationship between wine ratings and price by wine type.
sns.set(rc={"figure.figsize":(12, 8)})

sns.scatterplot(data=wine_df,
                x="points", 
                y="price", 
                hue="type", 
                s=200)
# Out:
# <AxesSubplot:xlabel='points', ylabel='price'>
